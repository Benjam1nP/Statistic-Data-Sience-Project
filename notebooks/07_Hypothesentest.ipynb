# %% [markdown]
# # 07 Hypothesentests
# ------------------------------------------------------------
# ## Hypothesen
#
# **1.**  Die Trinkgeld-Rate (Tip Percentage), gemessen als Verhältnis von Trinkgeld zu Gesamtbetrag, wird signifikant durch die
#     Tageszeit beeinflusst.
#
# **2.**
#
# **3.**
#
# **4.**  Es gibt eine Beste Zeit zum Taxifahren.
#
# **5.**
